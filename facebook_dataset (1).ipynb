# %% [markdown]
# # **Adding Dataset**

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_facebook.csv', sep=';')

# %%
df2.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df2.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df2.shape
# Out:
# (500, 19)

# %% [markdown]
# # **Creating Subsets**

# %%
# Subset 1
dfa = df2[['Page total likes', 'Post Month', 'Post Weekday']].loc[0:15]
dfa
# Out:
#     Page total likes  Post Month  Post Weekday
# 0             139441          12             4
# 1             139441          12             3
# 2             139441          12             3
# 3             139441          12             2
# 4             139441          12             2
# 5             139441          12             1
# 6             139441          12             1
# 7             139441          12             7
# 8             139441          12             7
# 9             139441          12             6
# 10            139441          12             5
# 11            139441          12             5
# 12            139441          12             5
# 13            139441          12             5
# 14            138414          12             4
# 15            138414          12             3

# %%
# Subset 2
dfb = df2[['Page total likes', 'Post Month', 'Post Weekday']].loc[16:30]
dfb
# Out:
#     Page total likes  Post Month  Post Weekday
# 16            138414          12             3
# 17            138414          12             2
# 18            138414          12             2
# 19            138414          12             1
# 20            138414          12             1
# 21            138414          12             7
# 22            138414          12             7
# 23            138414          12             7
# 24            138414          12             6
# 25            138458          12             6
# 26            138458          12             5
# 27            138458          12             5
# 28            138895          12             5
# 29            138895          12             4
# 30            138895          12             4

# %%
# Subset 3
dfc = df2[['Page total likes', 'Post Month', 'Post Weekday']].loc[31:50]
dfc
# Out:
#     Page total likes  Post Month  Post Weekday
# 31            138895          12             3
# 32            138895          12             3
# 33            138895          12             2
# 34            138895          12             2
# 35            138895          12             1
# 36            138895          12             1
# 37            138895          12             7
# 38            138895          12             7
# 39            138895          12             7
# 40            138895          12             6
# 41            138895          12             6
# 42            138353          12             5
# 43            138353          12             5
# 44            138353          12             4
# 45            138353          12             4
# 46            138353          12             3
# 47            138353          12             3
# 48            138353          12             2
# 49            138353          12             2
# ...

# %% [markdown]
# # **Merge Data**

# %%
merged_data = pd.concat([dfa,dfb,dfc])
merged_data
# Out:
#     Page total likes  Post Month  Post Weekday
# 0             139441          12             4
# 1             139441          12             3
# 2             139441          12             3
# 3             139441          12             2
# 4             139441          12             2
# 5             139441          12             1
# 6             139441          12             1
# 7             139441          12             7
# 8             139441          12             7
# 9             139441          12             6
# 10            139441          12             5
# 11            139441          12             5
# 12            139441          12             5
# 13            139441          12             5
# 14            138414          12             4
# 15            138414          12             3
# 16            138414          12             3
# 17            138414          12             2
# 18            138414          12             2
# ...

# %% [markdown]
# # **Sort Data**

# %%
sort_values = df2.sort_values("Page total likes", ascending=False)
sort_values
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # **Transposing data**

# %%
transposing = df2.transpose()
transposing
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # **Shape and Reshape data**

# %%
shape = df2.shape
shape
# Out:
# (500, 19)

# %%
pivot_table = pd.pivot_table(df2, index=['Type', 'Category'], values='comment')
pivot_table
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714

# %%
pivot_table.melt()
# Out:
#   variable      value
# 0  comment   2.900000
# 1  comment   2.000000
# 2  comment   2.000000
# 3  comment   5.897297
# 4  comment  11.692308
# 5  comment   6.913333
# 6  comment   4.333333
# 7  comment   9.921053
# 8  comment   2.750000
# 9  comment  12.285714
